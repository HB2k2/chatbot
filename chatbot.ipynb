# %%
import json
import string
import random
import os

import nltk
import numpy as np
from nltk.stem import WordNetLemmatizer
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Dropout
nltk.download("punkt")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\91939\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\91939\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
data_file = open("A:/NLP/chatbot/intents.json",encoding="utf-8").read()
data = json.loads(data_file)
# print(json.dumps(data, indent=4, sort_keys=True))

# %%
#4 Creating data_X and data_Y
words = [] #For Bow model/ vocabulary for patterns
classes = [] #For Bow model/ vocabulary for tags
data_X = [] #For storing each pattern
data_y = [] #For storing tag corresponding to each pattern in data_X
# Iterating over all the intents
for intent in data["intents"]:
    for pattern in intent["patterns"] :
        tokens = nltk.word_tokenize(pattern) # tokenize each pattern
        words.extend(tokens) # and append tokens to words
        data_X.append(pattern) # appending pattern to data_X
        data_y.append(intent["tag"]) # appending the associated tag to each pattern
    # adding the tag to the classes if it's not there already
    if intent["tag"] not in classes:
        classes.append(intent["tag"])

# initializing lemmatizer to get stem of words
lemmatizer = WordNetLemmatizer()

# lemmatize all the words in the vocab and convert them to lowercase
# if the words don't appear in punctuation
words = [lemmatizer.lemmatize(word.lower() ) for word in words if word not in string.punctuation]
# sorting the vocab and classes in alphabetical order and taking the # set to ensure no duplicates occur
words = sorted(set(words))
classes = sorted(set(classes))
print(words)
print(classes)
# Out:
# ["'s", '2', 'a', 'afternoon', 'age', 'am', 'are', 'ask', 'bad', 'born', 'boy', 'bye', 'can', 'do', 'doing', 'feel', 'feeling', 'fine', 'girl', 'good', 'goodbye', 'great', 'hello', 'help', 'here', 'hi', 'how', 'i', 'is', 'job', 'live', 'me', 'men', 'minute', 'morning', 'much', 'no', 'old', 'please', 'sad', 'sec', 'still', 'thank', 'thanks', 'there', 'today', 'too', 'up', 'very', 'wait', 'were', 'what', 'when', 'where', 'woman', 'work', 'you', 'your']
# ['action', 'actions', 'age', 'bad', 'city', 'feeling', 'good', 'goodbye', 'hello', 'job', 'men', 'noanswer', 'still there', 'thanks', 'wait', 'women']

# %%
#5 Text to Numbers
training = []
out_empty = [0] * len(classes)
# creating the bag of words model
for idx, doc in enumerate(data_X):
    bow = []
    text = lemmatizer.lemmatize(doc.lower())
    for word in words:
        bow.append(1) if word in text else bow.append(0)
    # mark the index of class that the current pattern is associated to
    output_row = list(out_empty)
    output_row[classes.index(data_y[idx] )] = 1
    # add the one hot encoded Bow and associated classes to training
    training. append([bow, output_row] )
# shuffle the data and convert it to an array
random.shuffle(training)
training = np.array(training, dtype=object)
# split the features and target labels
train_X = np.array(list(training[ :, 0]))
train_Y = np.array(list(training[ :, 1]))

# %%
#6 The Neural Network Model
model = Sequential()
model.add(Dense(128, input_shape=(len(train_X[0]),), activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(32, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(len(train_Y[0]), activation = "softmax"))
adam = tf. keras.optimizers.legacy.Adam(learning_rate=0.01, decay=1e-6)
model. compile(loss='categorical_crossentropy',optimizer=adam,metrics=["accuracy"])
print(model.summary())
model.fit(x=train_X, y=train_Y, epochs=250, verbose=1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               7552
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_3 (Dense)             (None, 16)                528
#
# =================================================================
# Total params: 18,416
# Trainable params: 18,416
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/250
# 2/2 [==============================] - 1s 10ms/step - loss: 2.8800 - accuracy: 0.0732
# Epoch 2/250
# 2/2 [==============================] - 0s 8ms/step - loss: 2.7430 - accuracy: 0.0732
# Epoch 3/250
# 2/2 [==============================] - 0s 5ms/step - loss: 2.7839 - accuracy: 0.1220
# Epoch 4/250
# 2/2 [==============================] - 0s 8ms/step - loss: 2.7093 - accuracy: 0.1463
# Epoch 5/250
# 2/2 [==============================] - 0s 8ms/step - loss: 2.6535 - accuracy: 0.1707
# Epoch 6/250
# 2/2 [==============================] - 0s 0s/step - loss: 2.4785 - accuracy: 0.2927
# Epoch 7/250
# 2/2 [==============================] - 0s 7ms/step - loss: 2.4879 - accuracy: 0.2195
# Epoch 8/250
# 2/2 [==============================] - 0s 8ms/step - loss: 2.4677 - accuracy: 0.1951
# Epoch 9/250
# 2/2 [==============================] - 0s 2ms/step - loss: 2.4344 - accuracy: 0.2195
# Epoch 10/250
# 2/2 [==============================] - 0s 7ms/step - loss: 2.4196 - accuracy: 0.2683
# Epoch 11/250
# 2/2 [==============================] - 0s 5ms/step - loss: 2.4025 - accuracy: 0.2683
# Epoch 12/250
# 2/2 [==============================] - 0s 5ms/step - loss: 2.3088 - accuracy: 0.2683
# Epoch 13/250
# 2/2 [==============================] - 0s 0s/step - loss: 2.0934 - accuracy: 0.2683
# Epoch 14/250
# 2/2 [==============================] - 0s 0s/step - loss: 2.1889 - accuracy: 0.3171
# Epoch 15/250
# 2/2 [==============================] - 0s 1ms/step - loss: 2.2477 - accuracy: 0.3415
# Epoch 16/250
# 2/2 [==============================] - 0s 0s/step - loss: 1.8477 - accuracy: 0.3902
# Epoch 17/250
# 2/2 [==============================] - 0s 10ms/step - loss: 2.3668 - accuracy: 0.2195
# Epoch 18/250
# 2/2 [==============================] - 0s 0s/step - loss: 2.0328 - accuracy: 0.3171
# Epoch 19/250
# 2/2 [==============================] - 0s 10ms/step - loss: 2.0385 - accuracy: 0.2683
# Epoch 20/250
# 2/2 [==============================] - 0s 0s/step - loss: 1.7999 - accuracy: 0.4878
# Epoch 21/250
# 2/2 [==============================] - 0s 0s/step - loss: 1.9712 - accuracy: 0.3659
# Epoch 22/250
# 2/2 [==============================] - 0s 10ms/step - loss: 1.9453 - accuracy: 0.3902
# Epoch 23/250
# 2/2 [==============================] - 0s 10ms/step - loss: 1.5692 - accuracy: 0.5122
# Epoch 24/250
# 2/2 [==============================] - 0s 0s/step - loss: 1.5374 - accuracy: 0.4146
# Epoch 25/250
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4953 - accuracy: 0.5610
# Epoch 26/250
# 2/2 [==============================] - 0s 10ms/step - loss: 1.5509 - accuracy: 0.4634
# Epoch 27/250
# 2/2 [==============================] - 0s 10ms/step - loss: 1.6677 - accuracy: 0.4390
# Epoch 28/250
# 2/2 [==============================] - 0s 12ms/step - loss: 1.4082 - accuracy: 0.4878
# Epoch 29/250
# 2/2 [==============================] - 0s 10ms/step - loss: 1.4248 - accuracy: 0.4878
# Epoch 30/250
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5576 - accuracy: 0.4878
# Epoch 31/250
# 2/2 [==============================] - 0s 9ms/step - loss: 1.3837 - accuracy: 0.4878
# Epoch 32/250
# 2/2 [==============================] - 0s 10ms/step - loss: 1.2763 - accuracy: 0.5854
# Epoch 33/250
# 2/2 [==============================] - 0s 2ms/step - loss: 1.3989 - accuracy: 0.5610
# Epoch 34/250
# 2/2 [==============================] - 0s 11ms/step - loss: 1.4216 - accuracy: 0.5122
# Epoch 35/250
# 2/2 [==============================] - 0s 6ms/step - loss: 1.3842 - accuracy: 0.4634
# Epoch 36/250
# 2/2 [==============================] - 0s 6ms/step - loss: 1.5475 - accuracy: 0.4146
# Epoch 37/250
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0543 - accuracy: 0.7073
# Epoch 38/250
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1700 - accuracy: 0.5854
# Epoch 39/250
# 2/2 [==============================] - 0s 6ms/step - loss: 1.1377 - accuracy: 0.5610
# Epoch 40/250
# 2/2 [==============================] - 0s 4ms/step - loss: 1.4145 - accuracy: 0.4878
# Epoch 41/250
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2588 - accuracy: 0.5854
# Epoch 42/250
# 2/2 [==============================] - 0s 5ms/step - loss: 1.5003 - accuracy: 0.4390
# Epoch 43/250
# 2/2 [==============================] - 0s 5ms/step - loss: 1.3403 - accuracy: 0.6098
# Epoch 44/250
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0087 - accuracy: 0.6341
# Epoch 45/250
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0405 - accuracy: 0.6098
# Epoch 46/250
# 2/2 [==============================] - 0s 5ms/step - loss: 1.2822 - accuracy: 0.5122
# Epoch 47/250
# 2/2 [==============================] - 0s 6ms/step - loss: 1.0154 - accuracy: 0.6585
# Epoch 48/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9223 - accuracy: 0.6341
# Epoch 49/250
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0113 - accuracy: 0.5610
# Epoch 50/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9785 - accuracy: 0.6098
# Epoch 51/250
# 2/2 [==============================] - 0s 11ms/step - loss: 0.9382 - accuracy: 0.6829
# Epoch 52/250
# 2/2 [==============================] - 0s 8ms/step - loss: 1.0338 - accuracy: 0.6585
# Epoch 53/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7824 - accuracy: 0.7073
# Epoch 54/250
# 2/2 [==============================] - 0s 7ms/step - loss: 1.2307 - accuracy: 0.6341
# Epoch 55/250
# 2/2 [==============================] - 0s 2ms/step - loss: 0.9474 - accuracy: 0.6829
# Epoch 56/250
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0005 - accuracy: 0.7317
# Epoch 57/250
# 2/2 [==============================] - 0s 384us/step - loss: 0.8905 - accuracy: 0.6829
# Epoch 58/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.9234 - accuracy: 0.7317
# Epoch 59/250
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0156 - accuracy: 0.6585
# Epoch 60/250
# 2/2 [==============================] - 0s 2ms/step - loss: 0.7157 - accuracy: 0.7317
# Epoch 61/250
# 2/2 [==============================] - 0s 8ms/step - loss: 1.2271 - accuracy: 0.4878
# Epoch 62/250
# 2/2 [==============================] - 0s 0s/step - loss: 0.9044 - accuracy: 0.7561
# Epoch 63/250
# 2/2 [==============================] - 0s 9ms/step - loss: 1.2361 - accuracy: 0.5854
# Epoch 64/250
# 2/2 [==============================] - 0s 9ms/step - loss: 1.1772 - accuracy: 0.5366
# Epoch 65/250
# 2/2 [==============================] - 0s 4ms/step - loss: 0.8380 - accuracy: 0.6829
# Epoch 66/250
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7799 - accuracy: 0.7561
# Epoch 67/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8176 - accuracy: 0.6585
# Epoch 68/250
# 2/2 [==============================] - 0s 0s/step - loss: 0.8169 - accuracy: 0.7561
# Epoch 69/250
# 2/2 [==============================] - 0s 18ms/step - loss: 0.8412 - accuracy: 0.7561
# Epoch 70/250
# 2/2 [==============================] - 0s 11ms/step - loss: 1.1396 - accuracy: 0.6829
# Epoch 71/250
# 2/2 [==============================] - 0s 7ms/step - loss: 1.0476 - accuracy: 0.7317
# Epoch 72/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6749 - accuracy: 0.7805
# Epoch 73/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7844 - accuracy: 0.7073
# Epoch 74/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5897 - accuracy: 0.7561
# Epoch 75/250
# 2/2 [==============================] - 0s 9ms/step - loss: 1.0126 - accuracy: 0.7073
# Epoch 76/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.8736 - accuracy: 0.7317
# Epoch 77/250
# 2/2 [==============================] - 0s 424us/step - loss: 0.7607 - accuracy: 0.6341
# Epoch 78/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7087 - accuracy: 0.7805
# Epoch 79/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8754 - accuracy: 0.6585
# Epoch 80/250
# 2/2 [==============================] - 0s 1ms/step - loss: 0.5035 - accuracy: 0.8293
# Epoch 81/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7056 - accuracy: 0.7317
# Epoch 82/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9471 - accuracy: 0.6341
# Epoch 83/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7184 - accuracy: 0.7561
# Epoch 84/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5421 - accuracy: 0.8049
# Epoch 85/250
# 2/2 [==============================] - 0s 1ms/step - loss: 0.5222 - accuracy: 0.8293
# Epoch 86/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6896 - accuracy: 0.7317
# Epoch 87/250
# 2/2 [==============================] - 0s 0s/step - loss: 0.8025 - accuracy: 0.7073
# Epoch 88/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6290 - accuracy: 0.7805
# Epoch 89/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.8389 - accuracy: 0.6829
# Epoch 90/250
# 2/2 [==============================] - 0s 1ms/step - loss: 0.7686 - accuracy: 0.7317
# Epoch 91/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.9033 - accuracy: 0.7561
# Epoch 92/250
# 2/2 [==============================] - 0s 0s/step - loss: 0.7220 - accuracy: 0.7073
# Epoch 93/250
# 2/2 [==============================] - 0s 11ms/step - loss: 0.7861 - accuracy: 0.6585
# Epoch 94/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7645 - accuracy: 0.7805
# Epoch 95/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6836 - accuracy: 0.7561
# Epoch 96/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5483 - accuracy: 0.7805
# Epoch 97/250
# 2/2 [==============================] - 0s 1ms/step - loss: 0.6416 - accuracy: 0.7805
# Epoch 98/250
# 2/2 [==============================] - 0s 4ms/step - loss: 0.7571 - accuracy: 0.7073
# Epoch 99/250
# 2/2 [==============================] - 0s 4ms/step - loss: 1.0125 - accuracy: 0.7073
# Epoch 100/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.8387 - accuracy: 0.7317
# Epoch 101/250
# 2/2 [==============================] - 0s 0s/step - loss: 0.5724 - accuracy: 0.7561
# Epoch 102/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5206 - accuracy: 0.8293
# Epoch 103/250
# 2/2 [==============================] - 0s 0s/step - loss: 0.8971 - accuracy: 0.6585
# Epoch 104/250
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5591 - accuracy: 0.8049
# Epoch 105/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6024 - accuracy: 0.7805
# Epoch 106/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7478 - accuracy: 0.7561
# Epoch 107/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6955 - accuracy: 0.7073
# Epoch 108/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9025 - accuracy: 0.7073
# Epoch 109/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6955 - accuracy: 0.7317
# Epoch 110/250
# 2/2 [==============================] - 0s 15ms/step - loss: 0.7265 - accuracy: 0.7805
# Epoch 111/250
# 2/2 [==============================] - 0s 3ms/step - loss: 0.8329 - accuracy: 0.7317
# Epoch 112/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8429 - accuracy: 0.7317
# Epoch 113/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5758 - accuracy: 0.7317
# Epoch 114/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5147 - accuracy: 0.7561
# Epoch 115/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5219 - accuracy: 0.9024
# Epoch 116/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6926 - accuracy: 0.7073
# Epoch 117/250
# 2/2 [==============================] - 0s 5ms/step - loss: 1.0241 - accuracy: 0.6829
# Epoch 118/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.7853 - accuracy: 0.6585
# Epoch 119/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5790 - accuracy: 0.8049
# Epoch 120/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4164 - accuracy: 0.8293
# Epoch 121/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5435 - accuracy: 0.8049
# Epoch 122/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4850 - accuracy: 0.7317
# Epoch 123/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8843 - accuracy: 0.6829
# Epoch 124/250
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5729 - accuracy: 0.7561
# Epoch 125/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6613 - accuracy: 0.7805
# Epoch 126/250
# 2/2 [==============================] - 0s 11ms/step - loss: 0.5826 - accuracy: 0.7561
# Epoch 127/250
# 2/2 [==============================] - 0s 3ms/step - loss: 0.5082 - accuracy: 0.7561
# Epoch 128/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.5681 - accuracy: 0.7317
# Epoch 129/250
# 2/2 [==============================] - 0s 0s/step - loss: 0.4855 - accuracy: 0.8293
# Epoch 130/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3158 - accuracy: 0.8780
# Epoch 131/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8330 - accuracy: 0.7805
# Epoch 132/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4520 - accuracy: 0.9268
# Epoch 133/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6606 - accuracy: 0.7805
# Epoch 134/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6567 - accuracy: 0.8049
# Epoch 135/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6310 - accuracy: 0.7317
# Epoch 136/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4681 - accuracy: 0.8293
# Epoch 137/250
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6703 - accuracy: 0.7805
# Epoch 138/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4508 - accuracy: 0.8537
# Epoch 139/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4777 - accuracy: 0.8049
# Epoch 140/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6347 - accuracy: 0.7805
# Epoch 141/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.8328 - accuracy: 0.7317
# Epoch 142/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.6072 - accuracy: 0.7073
# Epoch 143/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3193 - accuracy: 0.9024
# Epoch 144/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7721 - accuracy: 0.6829
# Epoch 145/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7630 - accuracy: 0.7561
# Epoch 146/250
# 2/2 [==============================] - 0s 652us/step - loss: 0.5897 - accuracy: 0.8780
# Epoch 147/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.8126 - accuracy: 0.7561
# Epoch 148/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6970 - accuracy: 0.7561
# Epoch 149/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5146 - accuracy: 0.8293
# Epoch 150/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3792 - accuracy: 0.8293
# Epoch 151/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4899 - accuracy: 0.7805
# Epoch 152/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5634 - accuracy: 0.8049
# Epoch 153/250
# 2/2 [==============================] - 0s 488us/step - loss: 0.5897 - accuracy: 0.7805
# Epoch 154/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6065 - accuracy: 0.8537
# Epoch 155/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5919 - accuracy: 0.8537
# Epoch 156/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3984 - accuracy: 0.8293
# Epoch 157/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3851 - accuracy: 0.8780
# Epoch 158/250
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6521 - accuracy: 0.8049
# Epoch 159/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.6924 - accuracy: 0.7073
# Epoch 160/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4252 - accuracy: 0.8537
# Epoch 161/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4121 - accuracy: 0.8537
# Epoch 162/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4158 - accuracy: 0.8049
# Epoch 163/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3310 - accuracy: 0.8780
# Epoch 164/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6037 - accuracy: 0.8293
# Epoch 165/250
# 2/2 [==============================] - 0s 4ms/step - loss: 0.6005 - accuracy: 0.8537
# Epoch 166/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8333 - accuracy: 0.7561
# Epoch 167/250
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6561 - accuracy: 0.7561
# Epoch 168/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4161 - accuracy: 0.8780
# Epoch 169/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4248 - accuracy: 0.8049
# Epoch 170/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5465 - accuracy: 0.7805
# Epoch 171/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4680 - accuracy: 0.7805
# Epoch 172/250
# 2/2 [==============================] - 0s 3ms/step - loss: 0.6063 - accuracy: 0.8049
# Epoch 173/250
# 2/2 [==============================] - 0s 4ms/step - loss: 0.4804 - accuracy: 0.8537
# Epoch 174/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5551 - accuracy: 0.8293
# Epoch 175/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5212 - accuracy: 0.7561
# Epoch 176/250
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5230 - accuracy: 0.8049
# Epoch 177/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.6675 - accuracy: 0.8293
# Epoch 178/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6170 - accuracy: 0.7805
# Epoch 179/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.6050 - accuracy: 0.7317
# Epoch 180/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3972 - accuracy: 0.8537
# Epoch 181/250
# 2/2 [==============================] - 0s 3ms/step - loss: 0.3955 - accuracy: 0.8049
# Epoch 182/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4734 - accuracy: 0.7805
# Epoch 183/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4624 - accuracy: 0.8293
# Epoch 184/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.3560 - accuracy: 0.8780
# Epoch 185/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3176 - accuracy: 0.8049
# Epoch 186/250
# 2/2 [==============================] - 0s 287us/step - loss: 0.7768 - accuracy: 0.7317
# Epoch 187/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4549 - accuracy: 0.8537
# Epoch 188/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7282 - accuracy: 0.7317
# Epoch 189/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3295 - accuracy: 0.8049
# Epoch 190/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.5985 - accuracy: 0.8537
# Epoch 191/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5359 - accuracy: 0.8780
# Epoch 192/250
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5078 - accuracy: 0.7805
# Epoch 193/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4312 - accuracy: 0.8780
# Epoch 194/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4906 - accuracy: 0.8049
# Epoch 195/250
# 2/2 [==============================] - 0s 3ms/step - loss: 0.7544 - accuracy: 0.8049
# Epoch 196/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.6359 - accuracy: 0.8293
# Epoch 197/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.6731 - accuracy: 0.7805
# Epoch 198/250
# 2/2 [==============================] - 0s 2ms/step - loss: 0.5383 - accuracy: 0.8049
# Epoch 199/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2717 - accuracy: 0.8780
# Epoch 200/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4413 - accuracy: 0.8537
# Epoch 201/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3127 - accuracy: 0.9268
# Epoch 202/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4544 - accuracy: 0.8293
# Epoch 203/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.7475 - accuracy: 0.8293
# Epoch 204/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4242 - accuracy: 0.8293
# Epoch 205/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2213 - accuracy: 0.9512
# Epoch 206/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4629 - accuracy: 0.8537
# Epoch 207/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4089 - accuracy: 0.8049
# Epoch 208/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4819 - accuracy: 0.8780
# Epoch 209/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4906 - accuracy: 0.8293
# Epoch 210/250
# 2/2 [==============================] - 0s 2ms/step - loss: 0.4705 - accuracy: 0.8537
# Epoch 211/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.4173 - accuracy: 0.7561
# Epoch 212/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7561 - accuracy: 0.7317
# Epoch 213/250
# 2/2 [==============================] - 0s 730us/step - loss: 0.4740 - accuracy: 0.8780
# Epoch 214/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.4998 - accuracy: 0.8293
# Epoch 215/250
# 2/2 [==============================] - 0s 12ms/step - loss: 0.2848 - accuracy: 0.8780
# Epoch 216/250
# 2/2 [==============================] - 0s 18ms/step - loss: 0.9351 - accuracy: 0.7805
# Epoch 217/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5450 - accuracy: 0.7805
# Epoch 218/250
# 2/2 [==============================] - 0s 355us/step - loss: 0.1829 - accuracy: 0.9268
# Epoch 219/250
# 2/2 [==============================] - 0s 11ms/step - loss: 0.3745 - accuracy: 0.8780
# Epoch 220/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.7027 - accuracy: 0.7805
# Epoch 221/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.4351 - accuracy: 0.8293
# Epoch 222/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.5314 - accuracy: 0.8293
# Epoch 223/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.8002 - accuracy: 0.8049
# Epoch 224/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3242 - accuracy: 0.9024
# Epoch 225/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3518 - accuracy: 0.9268
# Epoch 226/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.2193 - accuracy: 0.9024
# Epoch 227/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.5561 - accuracy: 0.7805
# Epoch 228/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4106 - accuracy: 0.8537
# Epoch 229/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.3895 - accuracy: 0.8293
# Epoch 230/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4445 - accuracy: 0.8537
# Epoch 231/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4261 - accuracy: 0.9024
# Epoch 232/250
# 2/2 [==============================] - 0s 2ms/step - loss: 0.3862 - accuracy: 0.8049
# Epoch 233/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.3365 - accuracy: 0.9268
# Epoch 234/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.7861 - accuracy: 0.7561
# Epoch 235/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.9093 - accuracy: 0.8049
# Epoch 236/250
# 2/2 [==============================] - 0s 4ms/step - loss: 0.5643 - accuracy: 0.7073
# Epoch 237/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.4016 - accuracy: 0.8537
# Epoch 238/250
# 2/2 [==============================] - 0s 5ms/step - loss: 0.2391 - accuracy: 0.9268
# Epoch 239/250
# 2/2 [==============================] - 0s 6ms/step - loss: 0.4450 - accuracy: 0.8049
# Epoch 240/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.2980 - accuracy: 0.8780
# Epoch 241/250
# 2/2 [==============================] - 0s 6ms/step - loss: 1.3758 - accuracy: 0.7561
# Epoch 242/250
# 2/2 [==============================] - 0s 7ms/step - loss: 1.1448 - accuracy: 0.7805
# Epoch 243/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.5071 - accuracy: 0.8537
# Epoch 244/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.2786 - accuracy: 0.8780
# Epoch 245/250
# 2/2 [==============================] - 0s 8ms/step - loss: 0.4184 - accuracy: 0.8537
# Epoch 246/250
# 2/2 [==============================] - 0s 1ms/step - loss: 0.3709 - accuracy: 0.8293
# Epoch 247/250
# 2/2 [==============================] - 0s 10ms/step - loss: 0.5904 - accuracy: 0.8537
# Epoch 248/250
# 2/2 [==============================] - 0s 0s/step - loss: 0.5312 - accuracy: 0.8049
# Epoch 249/250
# 2/2 [==============================] - 0s 9ms/step - loss: 0.3365 - accuracy: 0.8537
# Epoch 250/250
# 2/2 [==============================] - 0s 7ms/step - loss: 0.3295 - accuracy: 0.9024

# %%
#7 Preprocessing the Input
def clean_text(text):
    tokens = nltk.word_tokenize(text)
    tokens = [lemmatizer. lemmatize(word) for word in tokens]
    return tokens

def bag_of_words(text, vocab):
    tokens = clean_text(text)
    bow = [0] * len(vocab)
    for w in tokens:
        for idx, word in enumerate(vocab):
            if word == w:
                bow[idx] = 1
    return np. array (bow)

def pred_class(text, vocab, labels):
    bow = bag_of_words(text, vocab)
    result = model.predict(np.array([bow])) [0] #Extracting probabilities
    thresh = 0.5
    y_pred = [[indx, res] for indx, res in enumerate(result) if res > thresh]
    y_pred.sort(key=lambda x: x[1], reverse=True) #sorting by values of probability in decreasing order
    return_list = []
    for r in y_pred:
        return_list. append(labels [r[0]]) #Contains labels(tags) for highest probability
    return return_list

def get_response(intents_list, intents_json):
    if len(intents_list) == 0:
        result = "Sorry! I don't understand."
    else:
        tag = intents_list[0]
        list_of_intents = intents_json["intents"]
        for i in list_of_intents:
            if i["tag"] == tag:
                result = random.choice(i["responses"])
                break
    return result

# %%
# 8 Interacting with the chatbot
print("Press 0 if you don't want to chat with our ChatBot.")
result=""
while not result:
    message = input("")
    print(message)
    if message == "0":
        break
    intents = pred_class(message, words, classes)
    result = get_response(intents, data)
    print(result)
    result=""
# Out:
# Press 0 if you don't want to chat with our ChatBot.
# hi
# 1/1 [==============================] - 0s 20ms/step
# Good morning!
# wassup
# 1/1 [==============================] - 0s 26ms/step
# Sorry! I don't understand.
# bye
# 1/1 [==============================] - 0s 22ms/step
# See you soon!
# 0
